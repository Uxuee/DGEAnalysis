# %%
path = 'C:/Users/ariad/OneDrive/Desktop/Proyecto/DGEAnalysis/GWAS'
import pandas as pd
import numpy as np

# %%
score = pd.read_csv(path + "/MONDO_0002009_associations_export.tsv", sep="\t", index_col=0)

# %%
score
# Out:
#                          pValue pValueAnnotation riskFrequency orValue beta  \
# riskAllele
# rs6436132-T        3.000000e-09                -            NR    3.34    -
# rs184644645-TTATG  9.000000e-09                -            NR    4.88    -
# rs6028719-T        2.000000e-08                -            NR    1.85    -
# rs6028721-G        2.000000e-08                -            NR    1.85    -
# rs6028723-C        2.000000e-08                -            NR    1.85    -
# ...                         ...              ...           ...     ...  ...
# rs4129585-?        2.000000e-15                -            NR       -    -
# rs1615350-?        5.000000e-10                -            NR       -    -
# rs4244354-?        2.000000e-09                -            NR       -    -
# rs4298967-?        8.000000e-20                -            NR       -    -
# rs4380187-?        8.000000e-12                -            NR       -    -
#
# ...

# %%
traits = ["Clinical depression",
"Lifetime major depressive disorder (AutoComplete Impute and observed)",
"Lifetime major depressive disorder (AutoComplete Impute)",
"Lifetime major depressive disorder (MTAG)",
"Lifetime major depressive disorder (SoftImpute and observed)",
"Lifetime major depressive disorder (SoftImpute)",
"Major depressive disorder",
"Major depressive disorder (broad)",
"Major depressive disorder (ICD-10 coded)",
"Major depressive disorder (lifetime)",
"Major depressive disorder (MTAG)",
"Major depressive disorder (PheCode 296.22)",
"Major depressive disorder (probable)",
"Major depressive disorder (stressful life events interaction)",
"Major depressive disorder (unexposed to adversity)"]

# %%
score.iloc[:,7].isin(traits)
# Out:
# riskAllele
# rs6436132-T          False
# rs184644645-TTATG    False
# rs6028719-T          False
# rs6028721-G          False
# rs6028723-C          False
#                      ...
# rs4129585-?          False
# rs1615350-?          False
# rs4244354-?          False
# rs4298967-?          False
# rs4380187-?          False
# Name: traitName, Length: 3989, dtype: bool

# %%
filtered=score[score.iloc[:,7].isin(traits)]

# %%
filtered
# Out:
#                          pValue pValueAnnotation riskFrequency orValue  \
# riskAllele
# rs4435501-A        4.000000e-06                -            NR       -
# rs6893200-T        5.000000e-06        (females)            NR       -
# rs111404313-A      4.000000e-06        (females)            NR       -
# rs9648182-A        9.000000e-08        (females)          0.12       -
# rs10227749-T       4.000000e-06        (females)            NR       -
# ...                         ...              ...           ...     ...
# chr11:113370758-G  1.000000e-17                -        0.6416       -
# chr14:42076434-C   1.000000e-14                -         0.493       -
# rs6877087-?        8.000000e-08                -            NR       -
# rs17156280-C       2.000000e-07                -         0.142       -
# rs10485715-C       8.000000e-09                -         0.144       -
#
#                                     beta             ci          mappedGenes  \
# riskAllele
# ...
